# %%
# Implement Employee and SalesEmployee classes here

class Employee:
    def __init__(self,id,salary):
        self.id=id
        self.salary=salary
        print(f"{self.id} {self.salary}")
        

class SalesEmployee(Employee):
    def __init__(self,id,salary,sales):
        
        super().__init__(id,salary)
        self.sales=sales
        print(f"{self.id} {self.salary} {self.sales}")
    
        
        
        

inpt_id=int(input())
inpt_salary=int(input())
inpt_sales=int(input())

Emp=SalesEmployee(inpt_id,inpt_salary,inpt_sales)
# Out:
#  2002
#  350000
#  304
# 2002 350000
# 2002 350000 304
