# %%
import re

size = int(input())

while size > 0:
    number = input()

    if re.match(r'^[789][0-9]{9}$', number):
        print("YES")
    else:
        print("NO")

    size -= 1
# Out:
#  3
#  845263177
# NO
#  9564512658
# YES
#  1234567890
# NO

# %%
size=int(input())
# if size ==0:
#     return None
while size>0:
    inpt=input()
    if len(inpt)==10 and  inpt[0] in "789" and inpt.isdigit():
        print("YES")
    else:
        print("NO")
    size-=1

# __init__="__main__":
# Out:
#  2
#  956451122658
# NO
#  8564123789
# YES
